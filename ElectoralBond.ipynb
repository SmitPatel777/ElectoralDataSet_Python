# %%
# day5 task
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# '/Users/patelsmitnileshbhai/Documents/Data Analytics college/Day-6'

# %%
# Day-6
# ElectoralBond_DataSet

# %%
os.chdir(r"/Users/patelsmitnileshbhai/Documents/Data Analytics college/Day-6/drive-download-20240615T043507Z-001")
folder="/Users/patelsmitnileshbhai/Documents/Data Analytics college/Day-6/drive-download-20240615T043507Z-001"
os.listdir(folder)
# Out:
# ['redemption_data.xlsx',
#  'receiver.pdf',
#  '~$redemption_data.xlsx',
#  'top_5_bjp_donors.csv',
#  'top5_bjp_donors.xlsx',
#  'donors_data.xlsx',
#  'sender.pdf']

# %%
donors_data = pd.read_excel("donors_data.xlsx")

# %%
donors_data.head()
# Out:
#    Sr No.      Reference No  (URN) Journal Date Date of\nPurchase  \
# 0       1  00001201904120000001166   2019-04-12        2019-04-12
# 1       2  00001201904120000001166   2019-04-12        2019-04-12
# 2       3  00001201904120000001166   2019-04-12        2019-04-12
# 3       4  00001201904120000001166   2019-04-12        2019-04-12
# 4       5  00001201904120000001166   2019-04-12        2019-04-12
#
#   Date of Expiry Name of the Purchaser Prefix  Bond\nNumber  Denominations  \
# 0     2019-04-26   A B C INDIA LIMITED     TL         11448        1000000
# 1     2019-04-26   A B C INDIA LIMITED     TL         11447        1000000
# 2     2019-04-26   A B C INDIA LIMITED     TL         11441        1000000
# 3     2019-04-26   A B C INDIA LIMITED     OL          1113         100000
# 4     2019-04-26   A B C INDIA LIMITED     OL          1118         100000
#
#    Issue Branch Code  Issue Teller Status
# 0                  1       5899230   Paid
# ...

# %%
receiver_data =pd.read_excel("redemption_data.xlsx")

# %%
receiver_data.head()
# Out:
#    Sr No. Date of\nEncashment               Name of the Political Party  \
# 0       1          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5          2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix  Bond\nNumber  Denominations  \
# 0                     *******5199     OC           775       10000000
# 1                     *******5199     OC          3975       10000000
# 2                     *******5199     OC          3967       10000000
# 3                     *******5199     TL         10418        1000000
# 4                     *******5199     TL           126        1000000
#
#    Pay Branch\nCode  Pay Teller
# 0               800     2770121
# 1               800     2770121
# ...

# %%
donors_data.columns
# Out:
# Index(['Sr No.', 'Reference No  (URN)', 'Journal Date', 'Date of\nPurchase',
#        'Date of Expiry', 'Name of the Purchaser', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
#rename the column
donors_data.rename(columns = {'Reference No  (URN)':'ref_no', 'Date of\nPurchase':'purchase_date',
                              'Bond\nNumber':'bond_no','Denominations':'bond_amount'}, inplace= True)

# %%
donors_data.columns
# Out:
# Index(['Sr No.', 'ref_no', 'Journal Date', 'purchase_date', 'Date of Expiry',
#        'Name of the Purchaser', 'Prefix', 'bond_no', 'bond_amount',
#        'Issue Branch Code', 'Issue Teller', 'Status'],
#       dtype='object')

# %%
receiver_data.columns
# Out:
# Index(['Sr No.', 'Date of\nEncashment', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'Bond\nNumber',
#        'Denominations', 'Pay Branch\nCode', 'Pay Teller'],
#       dtype='object')

# %%
#rename the column
receiver_data.rename(columns = {'Bond\nNumber':'bond_no', 'Date of\nEncashment':'encash_date',
                              'Pay Branch\nCode':'branch_code'}, inplace = True)

# %%
receiver_data.columns
# Out:
# Index(['Sr No.', 'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'bond_no', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
donors_data.describe()
# Out:
#              Sr No.                   Journal Date  \
# count  18871.000000                          18871
# mean    9436.000000  2022-03-15 00:27:55.714058496
# min        1.000000            2019-04-12 00:00:00
# 25%     4718.500000            2021-04-09 00:00:00
# 50%     9436.000000            2022-07-06 00:00:00
# 75%    14153.500000            2023-07-10 00:00:00
# max    18871.000000            2024-01-11 00:00:00
# std     5447.732801                            NaN
#
#                        purchase_date                 Date of Expiry  \
# count                          18871                          18871
# mean   2022-03-15 00:28:27.763234304  2022-03-29 00:28:27.763234304
# min              2019-04-12 00:00:00            2019-04-26 00:00:00
# 25%              2021-04-09 00:00:00            2021-04-23 00:00:00
# 50%              2022-07-06 00:00:00            2022-07-20 00:00:00
# 75%              2023-07-10 00:00:00            2023-07-24 00:00:00
# ...

# %%
donors_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18871 entries, 0 to 18870
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sr No.                 18871 non-null  int64
#  1   ref_no                 18871 non-null  object
#  2   Journal Date           18871 non-null  datetime64[ns]
#  3   purchase_date          18871 non-null  datetime64[ns]
#  4   Date of Expiry         18871 non-null  datetime64[ns]
#  5   Name of the Purchaser  18871 non-null  object
#  6   Prefix                 18871 non-null  object
#  7   bond_no                18871 non-null  int64
#  8   bond_amount            18871 non-null  int64
#  9   Issue Branch Code      18871 non-null  int64
#  10  Issue Teller           18871 non-null  int64
#  11  Status                 18871 non-null  object
# dtypes: datetime64[ns](3), int64(5), object(4)
# memory usage: 1.7+ MB

# %%
donors_data.shape
# Out:
# (18871, 12)

# %%
#total amount of bond value which is bought
total_amount=donors_data['bond_amount'].sum()
total_amount_in_cr = total_amount / 10000000

total_amount_in_cr = round(total_amount_in_cr, 2)
print("Total amount of electrol bond which is bought is :",total_amount_in_cr,"Cr")
# Out:
# Total amount of electrol bond which is bought is : 12155.51 Cr

# %%
# sort the data according to bond_amount
donors_data.sort_values(by="bond_amount").head()
# Out:
#        Sr No.                   ref_no Journal Date purchase_date  \
# 1831     1832  00001201905080000001375   2019-05-08    2019-05-08
# 1842     1843  00001201905080000001375   2019-05-08    2019-05-08
# 1843     1844  00001201905080000001375   2019-05-08    2019-05-08
# 1844     1845  00001201905080000001375   2019-05-08    2019-05-08
# 15879   15880  01355202310110000003394   2023-10-11    2023-10-11
#
#       Date of Expiry       Name of the Purchaser Prefix  bond_no  bond_amount  \
# 1831      2019-05-22                 ITC LIMITED     OT     5017         1000
# 1842      2019-05-22                 ITC LIMITED     OT     5013         1000
# 1843      2019-05-22                 ITC LIMITED     OT     5012         1000
# 1844      2019-05-22                 ITC LIMITED     OT     5018         1000
# 15879     2023-10-25  BHACHIBEN KHAMUBHAI MANVAR     OT    20076         1000
#
#        Issue Branch Code  Issue Teller Status
# 1831                   1       5899230   Paid
# ...

# %%
# bond_amount in descending order
donors_data.sort_values(by="bond_amount",ascending=False)[['Name of the Purchaser','bond_amount']].head()
# Out:
#                      Name of the Purchaser  bond_amount
# 9435   FUTURE GAMING AND HOTEL SERVICES PR     10000000
# 10946                WELSPUN INDIA LIMITED     10000000
# 10934                      VEDANTA LIMITED     10000000
# 10935                      VEDANTA LIMITED     10000000
# 10936                      VEDANTA LIMITED     10000000

# %%
#Data select on multipe condition
# choose only the ITC Limited Company	
donors_data[(donors_data['Name of the Purchaser'])=="ITC LIMITED"].head()
# Out:
#       Sr No.                   ref_no Journal Date purchase_date  \
# 1799    1800  00001201905080000001375   2019-05-08    2019-05-08
# 1800    1801  00001201905080000001375   2019-05-08    2019-05-08
# 1801    1802  00001201905080000001375   2019-05-08    2019-05-08
# 1802    1803  00001201905080000001375   2019-05-08    2019-05-08
# 1803    1804  00001201905080000001375   2019-05-08    2019-05-08
#
#      Date of Expiry Name of the Purchaser Prefix  bond_no  bond_amount  \
# 1799     2019-05-22           ITC LIMITED     OC     4698     10000000
# 1800     2019-05-22           ITC LIMITED     OC     4686     10000000
# 1801     2019-05-22           ITC LIMITED     OC     4700     10000000
# 1802     2019-05-22           ITC LIMITED     OC     7361     10000000
# 1803     2019-05-22           ITC LIMITED     OC     4682     10000000
#
#       Issue Branch Code  Issue Teller Status
# 1799                  1       5899230   Paid
# 1800                  1       5899230   Paid
# ...

# %%
# total no of rows in the given data
len(donors_data[(donors_data['Name of the Purchaser'])=="ITC LIMITED"])
# Out:
# 46

# %%
#lets say i want to put mulitple condition like purcharser should be itc and bond_amount should be greater than or equal to 1cr
donors_data[(donors_data['Name of the Purchaser']=="ITC LIMITED") & (donors_data['bond_amount']>=10000000)]
# Out:
#       Sr No.                   ref_no Journal Date purchase_date  \
# 1799    1800  00001201905080000001375   2019-05-08    2019-05-08
# 1800    1801  00001201905080000001375   2019-05-08    2019-05-08
# 1801    1802  00001201905080000001375   2019-05-08    2019-05-08
# 1802    1803  00001201905080000001375   2019-05-08    2019-05-08
# 1803    1804  00001201905080000001375   2019-05-08    2019-05-08
#
#      Date of Expiry Name of the Purchaser Prefix  bond_no  bond_amount  \
# 1799     2019-05-22           ITC LIMITED     OC     4698     10000000
# 1800     2019-05-22           ITC LIMITED     OC     4686     10000000
# 1801     2019-05-22           ITC LIMITED     OC     4700     10000000
# 1802     2019-05-22           ITC LIMITED     OC     7361     10000000
# 1803     2019-05-22           ITC LIMITED     OC     4682     10000000
#
#       Issue Branch Code  Issue Teller Status
# 1799                  1       5899230   Paid
# 1800                  1       5899230   Paid
# ...

# %%
len(donors_data[(donors_data['Name of the Purchaser']=="ITC LIMITED") & (donors_data['bond_amount']>=10000000)])
# Out:
# 5

# %%
# to know the unique_donor in the data
unique_donors=donors_data['Name of the Purchaser'].unique()

# %%
type(unique_donors)
# Out:
# numpy.ndarray

# %%
unique_donors
# Out:
# array(['A B C INDIA LIMITED',
#        'ACROPOLIS MAINTENANCE SERVICES PRIVATE LIMITED',
#        'ARIHANT ENTERPRISES', ..., 'VEDIKA VANIJYA PVT LTD-SELF A/C',
#        'VIDUR GUPTA', 'VIHAAN AUTO VENTURES PRIVATE LIMITED'],
#       dtype=object)

# %%
type(unique_donors)
# Out:
# numpy.ndarray

# %%
unique_donors=pd.DataFrame(unique_donors,columns=['unique_donor_names'])

# %%
unique_donors
# Out:
#                                   unique_donor_names
# 0                                A B C INDIA LIMITED
# 1     ACROPOLIS MAINTENANCE SERVICES PRIVATE LIMITED
# 2                                ARIHANT ENTERPRISES
# 3                                 CHOUDHARY GARMENTS
# 4                          ESSEL MINING AND INDS LTD
# ...                                              ...
# 1315        SRI CHAITANYA STUDENTS FACILITY MANAGEME
# 1316             SYLVANUS BUILDERS AND DEVELOPERS LI
# 1317                 VEDIKA VANIJYA PVT LTD-SELF A/C
# 1318                                     VIDUR GUPTA
# 1319            VIHAAN AUTO VENTURES PRIVATE LIMITED
#
# [1320 rows x 1 columns]

# %%
# to see the coloumn in receiver_data
receiver_data.columns
# Out:
# Index(['Sr No.', 'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix', 'bond_no', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
receiver_data['Name of the Political Party'].unique()
# Out:
# array(['ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'BHARAT RASHTRA SAMITHI', 'BHARATIYA JANATA PARTY',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE', 'SHIVSENA',
#        'TELUGU DESAM PARTY',
#        'YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)',
#        'DRAVIDA MUNNETRA KAZHAGAM (DMK)', 'JANATA DAL ( SECULAR )',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'ALL INDIA TRINAMOOL CONGRESS', 'BIHAR PRADESH JANTA DAL(UNITED)',
#        'RASHTRIYA JANTA DAL', 'AAM AADMI PARTY',
#        'ADYAKSHA SAMAJVADI PARTY', 'SHIROMANI AKALI DAL',
#        'JHARKHAND MUKTI MORCHA', 'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'BIJU JANATA DAL', 'GOA FORWARD PARTY',
#        'MAHARASHTRAWADI GOMNTAK PARTY', 'SIKKIM KRANTIKARI MORCHA',
#        'JANASENA PARTY', 'SIKKIM DEMOCRATIC FRONT'], dtype=object)

# %%
#identify how many parties are there in receiver_data
receiver_data['Name of the Political Party'].unique()
# Out:
# array(['ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM',
#        'BHARAT RASHTRA SAMITHI', 'BHARATIYA JANATA PARTY',
#        'PRESIDENT, ALL INDIA CONGRESS COMMITTEE', 'SHIVSENA',
#        'TELUGU DESAM PARTY',
#        'YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)',
#        'DRAVIDA MUNNETRA KAZHAGAM (DMK)', 'JANATA DAL ( SECULAR )',
#        'NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH',
#        'ALL INDIA TRINAMOOL CONGRESS', 'BIHAR PRADESH JANTA DAL(UNITED)',
#        'RASHTRIYA JANTA DAL', 'AAM AADMI PARTY',
#        'ADYAKSHA SAMAJVADI PARTY', 'SHIROMANI AKALI DAL',
#        'JHARKHAND MUKTI MORCHA', 'JAMMU AND KASHMIR NATIONAL CONFERENCE',
#        'BIJU JANATA DAL', 'GOA FORWARD PARTY',
#        'MAHARASHTRAWADI GOMNTAK PARTY', 'SIKKIM KRANTIKARI MORCHA',
#        'JANASENA PARTY', 'SIKKIM DEMOCRATIC FRONT'], dtype=object)

# %%
#want to see not just unique party but how many times that info is comming the raw data
receiver_data['Name of the Political Party'].value_counts()
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                          8633
# ALL INDIA TRINAMOOL CONGRESS                                    3305
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                         3146
# BHARAT RASHTRA SAMITHI                                          1806
# BIJU JANATA DAL                                                  861
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  648
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)     472
# SHIVSENA                                                         355
# TELUGU DESAM PARTY                                               279
# AAM AADMI PARTY                                                  245
# RASHTRIYA JANTA DAL                                              150
# NATIONALIST CONGRESS PARTY MAHARASHTRA PRADESH                   121
# JANATA DAL ( SECULAR )                                            75
# ...

# %%
#total amount of bond value which is bought
total_amount=donors_data['bond_amount'].sum()
total_amount_in_cr = total_amount / 10000000

total_amount_in_cr = round(total_amount_in_cr, 2)
print("Total amount of electrol bond which is bought is :",total_amount_in_cr,"Cr")
# Out:
# Total amount of electrol bond which is bought is : 12155.51 Cr

# %%
# How much each party got as the bond amount

receiver_data.groupby(['Name of the Political Party'])['Denominations'].sum()
# Out:
# Name of the Political Party
# AAM AADMI PARTY                                                   654500000
# ADYAKSHA SAMAJVADI PARTY                                          140500000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                           60500000
# ALL INDIA TRINAMOOL CONGRESS                                    16095314000
# BHARAT RASHTRA SAMITHI                                          12147099000
# BHARATIYA JANATA PARTY                                          60605111000
# BIHAR PRADESH JANTA DAL(UNITED)                                   140000000
# BIJU JANATA DAL                                                  7755000000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                  6390000000
# GOA FORWARD PARTY                                                   3500000
# JAMMU AND KASHMIR NATIONAL CONFERENCE                               5000000
# JANASENA PARTY                                                    210000000
# ...

# %%
party_with_fund=pd.DataFrame(receiver_data.groupby(['Name of the Political Party'])['Denominations'].sum())

# %%
party_with_fund.reset_index(inplace=True)

# %%
party_with_fund.columns
# Out:
# Index(['Name of the Political Party', 'Denominations'], dtype='object')

# %%
party_with_fund['Denominations']  = party_with_fund['Denominations']  / 10000000
party_with_fund['Denominations'] = round(party_with_fund['Denominations'] ,2)
party_with_fund
# Out:
#                           Name of the Political Party  Denominations
# 0                                     AAM AADMI PARTY          65.45
# 1                            ADYAKSHA SAMAJVADI PARTY          14.05
# 2            ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM           6.05
# 3                        ALL INDIA TRINAMOOL CONGRESS        1609.53
# 4                              BHARAT RASHTRA SAMITHI        1214.71
# 5                              BHARATIYA JANATA PARTY        6060.51
# 6                     BIHAR PRADESH JANTA DAL(UNITED)          14.00
# 7                                     BIJU JANATA DAL         775.50
# 8                     DRAVIDA MUNNETRA KAZHAGAM (DMK)         639.00
# 9                                   GOA FORWARD PARTY           0.35
# 10              JAMMU AND KASHMIR NATIONAL CONFERENCE           0.50
# 11                                     JANASENA PARTY          21.00
# 12                             JANATA DAL ( SECULAR )          43.50
# ...

# %%
#  TOP 5 Parties get the highest fund
party_with_fund.sort_values(by="Denominations",ascending=False).head
# Out:
# <bound method NDFrame.head of                           Name of the Political Party  Denominations
# 5                              BHARATIYA JANATA PARTY        6060.51
# 3                        ALL INDIA TRINAMOOL CONGRESS        1609.53
# 16            PRESIDENT, ALL INDIA CONGRESS COMMITTEE        1421.87
# 4                              BHARAT RASHTRA SAMITHI        1214.71
# 7                                     BIJU JANATA DAL         775.50
# 8                     DRAVIDA MUNNETRA KAZHAGAM (DMK)         639.00
# 23  YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU C...         337.00
# 22                                 TELUGU DESAM PARTY         218.88
# 19                                           SHIVSENA         159.38
# 17                                RASHTRIYA JANTA DAL          73.50
# 0                                     AAM AADMI PARTY          65.45
# 12                             JANATA DAL ( SECULAR )          43.50
# ...

# %%
donors_data.head()
# Out:
#    Sr No.                   ref_no Journal Date purchase_date Date of Expiry  \
# 0       1  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 1       2  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 2       3  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 3       4  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 4       5  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
#
#   Name of the Purchaser Prefix  bond_no  bond_amount  Issue Branch Code  \
# 0   A B C INDIA LIMITED     TL    11448      1000000                  1
# 1   A B C INDIA LIMITED     TL    11447      1000000                  1
# 2   A B C INDIA LIMITED     TL    11441      1000000                  1
# 3   A B C INDIA LIMITED     OL     1113       100000                  1
# 4   A B C INDIA LIMITED     OL     1118       100000                  1
#
#    Issue Teller Status
# 0       5899230   Paid
# ...

# %%
receiver_data.head()
# Out:
#    Sr No. encash_date               Name of the Political Party  \
# 0       1  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1       2  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2       3  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 3       4  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4       5  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
#
#   Account no. of\nPolitical Party Prefix  bond_no  Denominations  branch_code  \
# 0                     *******5199     OC      775       10000000          800
# 1                     *******5199     OC     3975       10000000          800
# 2                     *******5199     OC     3967       10000000          800
# 3                     *******5199     TL    10418        1000000          800
# 4                     *******5199     TL      126        1000000          800
#
#    Pay Teller
# 0     2770121
# 1     2770121
# 2     2770121
# 3     2770121
# 4     2770121

# %%
combined_data=pd.merge(donors_data,receiver_data,on="bond_no",how="inner")

# %%
combined_data.head()
# Out:
#    Sr No._x                   ref_no Journal Date purchase_date  \
# 0         1  00001201904120000001166   2019-04-12    2019-04-12
# 1         1  00001201904120000001166   2019-04-12    2019-04-12
# 2     11034  00001202211150000002706   2022-11-15    2022-11-15
# 3     11034  00001202211150000002706   2022-11-15    2022-11-15
# 4         2  00001201904120000001166   2019-04-12    2019-04-12
#
#   Date of Expiry        Name of the Purchaser Prefix_x  bond_no  bond_amount  \
# 0     2019-04-26          A B C INDIA LIMITED       TL    11448      1000000
# 1     2019-04-26          A B C INDIA LIMITED       TL    11448      1000000
# 2     2022-11-29  IFB AGRO INDUSTRIES LIMITED       OC    11448     10000000
# 3     2022-11-29  IFB AGRO INDUSTRIES LIMITED       OC    11448     10000000
# 4     2019-04-26          A B C INDIA LIMITED       TL    11447      1000000
#
#    Issue Branch Code  Issue Teller Status  Sr No._y encash_date  \
# ...

# %%
combined_data.columns
# Out:
# Index(['Sr No._x', 'ref_no', 'Journal Date', 'purchase_date', 'Date of Expiry',
#        'Name of the Purchaser', 'Prefix_x', 'bond_no', 'bond_amount',
#        'Issue Branch Code', 'Issue Teller', 'Status', 'Sr No._y',
#        'encash_date', 'Name of the Political Party',
#        'Account no. of\nPolitical Party', 'Prefix_y', 'Denominations',
#        'branch_code', 'Pay Teller'],
#       dtype='object')

# %%
corr_info=combined_data[['Name of the Purchaser','bond_no','bond_amount','Name of the Political Party']]

# %%
corr_info.head()
# Out:
#          Name of the Purchaser  bond_no  bond_amount  \
# 0          A B C INDIA LIMITED    11448      1000000
# 1          A B C INDIA LIMITED    11448      1000000
# 2  IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 3  IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 4          A B C INDIA LIMITED    11447      1000000
#
#                Name of the Political Party
# 0                   BHARATIYA JANATA PARTY
# 1  PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 2                   BHARATIYA JANATA PARTY
# 3  PRESIDENT, ALL INDIA CONGRESS COMMITTEE
# 4                   BHARATIYA JANATA PARTY

# %%
# who are the top donor of Bjp
bjp_data=corr_info[corr_info['Name of the Political Party']=='BHARATIYA JANATA PARTY']

# %%
bjp_data
# Out:
#                 Name of the Purchaser  bond_no  bond_amount  \
# 0                 A B C INDIA LIMITED    11448      1000000
# 2         IFB AGRO INDUSTRIES LIMITED    11448     10000000
# 4                 A B C INDIA LIMITED    11447      1000000
# 6      WESTWELL GASES PRIVATE LIMITED    11447     10000000
# 8                 A B C INDIA LIMITED    11441      1000000
# ...                               ...      ...          ...
# 28673               RUNGTA SONS P LTD    15783     10000000
# 28674               RUNGTA SONS P LTD    17831     10000000
# 28675               RUNGTA SONS P LTD    16480     10000000
# 28676               RUNGTA SONS P LTD    17819     10000000
# 28677               RUNGTA SONS P LTD    16476     10000000
#
#       Name of the Political Party
# 0          BHARATIYA JANATA PARTY
# 2          BHARATIYA JANATA PARTY
# 4          BHARATIYA JANATA PARTY
# 6          BHARATIYA JANATA PARTY
# 8          BHARATIYA JANATA PARTY
# ...

# %%
grouped_data=bjp_data.groupby('Name of the Purchaser')['bond_amount'].sum()

# %%
top_5_bjp_donors=grouped_data.sort_values(ascending=False).head()

# %%
top_5_bjp_donors=top_5_bjp_donors.reset_index()

# %%
top_5_bjp_donors
# Out:
#                             Name of the Purchaser  bond_amount
# 0  MEGHA ENGINEERING AND INFRASTRUCTURES LI MITED   6010000000
# 1                   QWIKSUPPLYCHAINPRIVATELIMITED   5640000000
# 2                                 VEDANTA LIMITED   3229500000
# 3                           BHARTI AIRTEL LIMITED   1860000000
# 4                                   MADANLAL LTD.   1820000000

# %%
top_5_bjp_donors.to_excel(r"top5_bjp_donors.xlsx")

# %%
import os
os.getcwd()
# Out:
# '/Users/patelsmitnileshbhai/Documents/Data Analytics college/Day-6/drive-download-20240615T043507Z-001'

# %%
# unique bond no
unique_bond_no_in_receiver_data=receiver_data['bond_no'].unique()

# %%
# unique bond no in receivers
unique_bond_no_in_receiver_data=list(unique_bond_no_in_receiver_data)

# %%
# unique bond no in donors
unique_bond_no_in_donors_data=donors_data['bond_no'].unique()
unique_bond_no_in_donors_data=list(unique_bond_no_in_donors_data)

# %%
difference = set(unique_bond_no_in_receiver_data) - set(unique_bond_no_in_donors_data)

# %%
len(difference)
# Out:
# 860

# %%
# bond_no not found/match
bond_no_match_not_found=list(difference)

# %%
match_not_found_donor = receiver_data[receiver_data['bond_no'].isin(difference)]

# %%
match_not_found_donor
# Out:
#       Sr No. encash_date               Name of the Political Party  \
# 0          1  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 1          2  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 2          3  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 4          5  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# 5          6  2019-04-12  ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM
# ...      ...         ...                                       ...
# 2801    2802  2019-04-25                    BHARATIYA JANATA PARTY
# 2804    2805  2019-04-25                    BHARATIYA JANATA PARTY
# 2853    2854  2019-04-25                                  SHIVSENA
# 2854    2855  2019-04-25                                  SHIVSENA
# 2855    2856  2019-04-25                                  SHIVSENA
#
#      Account no. of\nPolitical Party Prefix  bond_no  Denominations  \
# 0                        *******5199     OC      775       10000000
# ...

# %%
#total no  not found amount in donor
match_not_found_in_donor['Denominations'].sum()
# Out:
# 5345110000

# %%
# according to each parties
x=match_not_found_in_donor.groupby(['Name of the Political Party'])['Denominations'].sum()

# %%
x.sort_values(ascending = False)
# Out:
# Name of the Political Party
# BHARATIYA JANATA PARTY                                          4132000000
# PRESIDENT, ALL INDIA CONGRESS COMMITTEE                          548710000
# BHARAT RASHTRA SAMITHI                                           230500000
# ALL INDIA TRINAMOOL CONGRESS                                     130000000
# YSR  CONGRESS PARTY  (YUVAJANA SRAMIKA RYTHU CONGRESS PARTY)      70500000
# DRAVIDA MUNNETRA KAZHAGAM (DMK)                                   60000000
# TELUGU DESAM PARTY                                                60000000
# ALL INDIA ANNA DRAVIDA MUNNETRA KAZHAGAM                          45400000
# SHIVSENA                                                          40300000
# BIHAR PRADESH JANTA DAL(UNITED)                                   20000000
# ADYAKSHA SAMAJVADI PARTY                                           7700000
# Name: Denominations, dtype: int64

# %%
# date and year wish bond purchase/claimed
donors_data.head()
# Out:
#    Sr No.                   ref_no Journal Date purchase_date Date of Expiry  \
# 0       1  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 1       2  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 2       3  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 3       4  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 4       5  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
#
#   Name of the Purchaser Prefix  bond_no  bond_amount  Issue Branch Code  \
# 0   A B C INDIA LIMITED     TL    11448      1000000                  1
# 1   A B C INDIA LIMITED     TL    11447      1000000                  1
# 2   A B C INDIA LIMITED     TL    11441      1000000                  1
# 3   A B C INDIA LIMITED     OL     1113       100000                  1
# 4   A B C INDIA LIMITED     OL     1118       100000                  1
#
#    Issue Teller Status
# 0       5899230   Paid
# ...

# %%
donors_data['purchase_date_new']=pd.to_datetime(donors_data['purchase_date'])
donors_data['purchase_date_new'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 18871 entries, 0 to 18870
# Series name: purchase_date_new
# Non-Null Count  Dtype
# --------------  -----
# 18871 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 147.6 KB

# %%
donors_data['purchase_date_year'] = donors_data['purchase_date_new'].dt.year

# %%
donors_data.head()
# Out:
#    Sr No.                   ref_no Journal Date purchase_date Date of Expiry  \
# 0       1  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 1       2  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 2       3  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 3       4  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
# 4       5  00001201904120000001166   2019-04-12    2019-04-12     2019-04-26
#
#   Name of the Purchaser Prefix  bond_no  bond_amount  Issue Branch Code  \
# 0   A B C INDIA LIMITED     TL    11448      1000000                  1
# 1   A B C INDIA LIMITED     TL    11447      1000000                  1
# 2   A B C INDIA LIMITED     TL    11441      1000000                  1
# 3   A B C INDIA LIMITED     OL     1113       100000                  1
# 4   A B C INDIA LIMITED     OL     1118       100000                  1
#
#    Issue Teller Status purchase_date_new  purchase_date_year
# ...

# %%
# acc to year sum of the bond
donors_data.groupby(['purchase_date_year'])['bond_amount'].sum()
# Out:
# purchase_date_year
# 2019    17661280000
# 2020     3639601000
# 2021    15022927000
# 2022    37048576000
# 2023    42464745000
# 2024     5718003000
# Name: bond_amount, dtype: int64
